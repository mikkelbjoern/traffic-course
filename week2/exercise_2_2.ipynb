# %%
# Load in the excel data
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Load in the data
data = pd.read_excel('Week2_Exercise2_data.xlsx')
data
# Out:
# /home/mbg/.local/lib/python3.10/site-packages/matplotlib/projections/__init__.py:63: UserWarning: Unable to import Axes3D. This may be due to multiple versions of Matplotlib being installed (e.g. as a system package and as a pip package). As a result, the 3D projection is not available.
#   warnings.warn("Unable to import Axes3D. This may be due to multiple versions of "
#      Trips  Income  Cars  Age  Male  Trips1
# 0        3     320     1   60     1       3
# 1        2       0     2   13     1       2
# 2        6     550     2   64     0       5
# 3        2       0     1   11     0       2
# 4        5     120     2   65     0       5
# ..     ...     ...   ...  ...   ...     ...
# 995      0     115     1   80     1       0
# 996      2     380     1   55     1       2
# 997      2     300     1   52     1       2
# 998      1       0     2   11     0       1
# 999      0     200     1   63     1       0
#
# [1000 rows x 6 columns]

# %%
# Plot the distribution of the Trips1 variable

plt.hist(data['Trips1'], bins=20, color='blue', edgecolor='black', label='Trips1')
plt.xlabel('Trips1')

plt.show()

# %%
# Do summary statistics of the Trips1 variable 
data['Trips1'].describe()
# Out:
# count    1000.000000
# mean        2.841000
# std         1.621218
# min         0.000000
# 25%         2.000000
# 50%         3.000000
# 75%         4.000000
# max         5.000000
# Name: Trips1, dtype: float64

# %%
# Plot correlation matrix
import seaborn as sns

modified_dataset = data.copy()
# Drop the original nun-censored Trips variable
modified_dataset.drop('Trips', axis=1, inplace=True)

corr = modified_dataset.corr()

# Ignore the diagonal values
for i in range(corr.shape[0]):
    corr.iloc[i,i] = np.nan

# Use blue as good fit, red as bad fit
sns.heatmap(corr, annot=True, cmap='coolwarm')

plt.show()
